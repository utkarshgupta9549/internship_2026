# %%
# Dictionary Example

student = {
    "name": "Utkarsh",
    "age": 20,
    "course": "CSE"
}

print("Student Details:")
print(student)

# Access value
print("Name:", student["name"])

# Add new item
student["college"] = "SKIT"

# Update value
student["age"] = 21

print("Updated Dictionary:")
print(student)
# Out:
# Student Details:
# {'name': 'Utkarsh', 'age': 20, 'course': 'CSE'}
# Name: Utkarsh
# Updated Dictionary:
# {'name': 'Utkarsh', 'age': 21, 'course': 'CSE', 'college': 'SKIT'}

# %%
# Tuple Example

numbers = (10, 20, 30, 40, 50)

print("Tuple:", numbers)

# Access elements
print("First Element:", numbers[0])
print("Last Element:", numbers[-1])

# Length of tuple
print("Length:", len(numbers))
# Out:
# Tuple: (10, 20, 30, 40, 50)
# First Element: 10
# Last Element: 50
# Length: 5

# %%
# Set Example

fruits = {"apple", "banana", "mango"}

print("Original Set:", fruits)

# Add element
fruits.add("orange")

# Remove element
fruits.remove("banana")

print("Updated Set:", fruits)
# Out:
# Original Set: {'mango', 'banana', 'apple'}
# Updated Set: {'orange', 'mango', 'apple'}

# %%
# Functions for basic math operations

def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def multi(a, b):
    return a * b

def div(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not possible"

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))


print("Addition =", add(num1, num2))
print("Subtraction =", sub(num1, num2))
print("Multiplication =", multi(num1, num2))
print("Division =", div(num1, num2))
# Out:
# Addition = 13
# Subtraction = 3
# Multiplication = 40
# Division = 1.6

# %%
# Program to check palindrome number

num = int(input("Enter a number: "))

original = num
reverse = 0

while num > 0:
    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

if original == reverse:
    print(original, "is a Palindrome Number")
else:
    print(original, "is not a Palindrome Number")
# Out:
# 12321 is a Palindrome Number
